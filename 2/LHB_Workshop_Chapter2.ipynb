# %% [markdown]
# # บทที่ 2: การจัดการและเตรียมข้อมูล (Data Manipulation & Preparation)
#
#
# ---
#
#
# **บริษัท:** บริษัท แลนด์ แอนด์ เฮ้าส์ จำกัด (มหาชน) | Land & Houses
# **ผู้บรรยาย:** ผู้ช่วยศาสตราจารย์ ดร.วสิศ ลิ้มประเสริฐ
# **วันที่:** 11 พฤศจิกายน 2025

# %% [markdown]
# ## Executive Summary
#
# บทที่ 2 มุ่งสอนการจัดการและเตรียมข้อมูลโดยใช้ Pandas ซึ่งเป็นเครื่องมือหลักสำหรับงาน Data Science ในงานจริงที่ข้อมูลมาเป็นไฟล์จำนวนมาก เช่น CSV/Excel. ผู้เรียนจะได้เข้าใจความแตกต่างระหว่าง Series และ DataFrame, วิธีการนำเข้าข้อมูลด้วย pd.read_csv / pd.read_excel, และแนวทางการสำรวจข้อมูลเบื้องต้นด้วย head(), info(), describe() เพื่อเป็นนักสืบข้อมูลก่อนวิเคราะห์.
#
# นอกจากนี้ครอบคลุมเทคนิคสำคัญในการทำความสะอาดข้อมูล เช่น การจัดการค่าว่างด้วย fillna/dropna, การแปลงประเภทข้อมูลด้วย astype/ pd.to_datetime/ pd.to_numeric, และการลบแถว/คอลัมน์ที่ไม่จำเป็นหรือซ้ำซ้อน. สุดท้ายเป็นการเปลี่ยนรูปข้อมูล (filtering, selecting), รวมตาราง (concat, merge) และตัวอย่าง Workshop เชิงปฏิบัติที่สามารถรันได้ทันที เพื่อให้ผู้เรียนพร้อมนำไปใช้กับ Data Pipeline ในงานจริง.

# %% [markdown]
# ## Key Takeaways
#
# - เข้าใจ DataFrame และ Series และวิธีสร้างจาก List of Dicts
# - ใช้ Pandas ในการนำเข้า สำรวจ และทำความสะอาดข้อมูล (fillna, to_datetime, drop_duplicates)
# - กรองและรวมข้อมูล (filtering, merge, concat) เพื่อเตรียมข้อมูลสำหรับการวิเคราะห์ต่อไป

# %% [markdown]
# ## Dependencies & Setup

# %%
# ติดตั้ง dependency ที่จำเป็นสำหรับการรันตัวอย่างใน Notebook นี้
# รันเพียงครั้งเดียวใน environment ของคุณ

# !pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in /home/wasit/miniconda3/envs/python_data_prep/lib/python3.10/site-packages (2.3.3)
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy>=1.22.4 in /home/wasit/miniconda3/envs/python_data_prep/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/wasit/miniconda3/envs/python_data_prep/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/wasit/miniconda3/envs/python_data_prep/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/wasit/miniconda3/envs/python_data_prep/lib/python3.10/site-packages (from pandas) (2025.2)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: six>=1.5 in /home/wasit/miniconda3/envs/python_data_prep/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]━━ 1/2 [openpyxl]
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %% [markdown]
# ## Section 2.1 — รู้จักกับ Pandas (Introduction to Pandas)
# ### Demo (ตัวอย่าง): สร้าง DataFrame จาก List of Dictionaries
# สรุป: DataFrame คือโครงสร้างหลัก (ตารางเหมือน Excel) และ Series คือคอลัมน์เดียว ใช้ pd.DataFrame และ pd.Series เพื่อสร้างจาก List of Dicts

# %%
import pandas as pd

customer_list = [
    {'cif': 12345, 'name': 'Mr. A', 'dpd': 15},
    {'cif': 12346, 'name': 'Ms. B', 'dpd': 91},
    {'cif': 12347, 'name': 'Mr. C', 'dpd': 0}
]

df_from_list = pd.DataFrame(customer_list)
df_from_list.head()
# Out:
#      cif   name  dpd
# 0  12345  Mr. A   15
# 1  12346  Ms. B   91
# 2  12347  Mr. C    0

# %%
series = pd.Series([{'cif': 12348,'name': 'Mr. D','dpd': 30},
                            {'cif': 12349,'name': 'Mr. E','dpd': 45}])
series
# Out:
# 0    {'cif': 12348, 'name': 'Mr. D', 'dpd': 30}
# 1    {'cif': 12349, 'name': 'Mr. E', 'dpd': 45}
# dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ## Section 2.2 — การนำเข้าและสำรวจข้อมูล (Data Acquisition & Exploration)
#
# ### 2.2.1 การอ่านข้อมูล (Data Input)
#
# ตัวอย่างการอ่านไฟล์ CSV / Excel ด้วย Pandas

# %%
# อ่านไฟล์ CSV / Excel
import pandas as pd

df_tran = pd.read_csv('Transection_20240731.csv', encoding='utf-8-sig', sep='|')
# df_tran = pd.read_excel('Transection_20240731.xlsx')
df_perf = pd.read_excel('Performance.xlsx', sheet_name='Sheet1')

# %% [markdown]
# ---

# %% [markdown]
# ### 2.2.2 การสำรวจข้อมูล (Exploration)
#
# ฟังก์ชันสำคัญ: `head()`, `tail()`, `shape`, `info()`, `describe()`, `value_counts()`

# %%
# ตัวอย่างการสำรวจเบื้องต้น
print(df_tran.shape)
df_tran.head()
# Out:
# (1116, 73)
#     FRPDATE  FRLDATE   FORDATE  FMATDATE  FCUSNO      FACCNO FLNTYP  FACCSTS  \
# 0  20240731        0  20110620  20250531   92953  7653161903      O        1
# 1  20240731        0  20220325  20250331   81681  9774723846      O        1
# 2  20240731        0  20101027  20250228   83867  7735375216      O        1
# 3  20240731        0  20210324  20250228   37293  4400759345      O        1
# 4  20240731        0  20160512  20250831   24128  7035068271      O        1
#
#   FPRODTY  FNPLFDTE  ... FCUSTSIZE  FBUSTYPE FODTOPUP FSGMCOD FCARID00  \
# 0      AA         0  ...         B  56477110      NaN    RSME        A
# 1      AA         0  ...         B  56471900      NaN     SME        A
# 2      AA         0  ...         B  61681031      NaN    RSME        A
# 3      AA         0  ...         B  52259210      NaN     SME        A
# 4      AA         0  ...         B  58551010      NaN     SME        A
#
#   FDPDUE00 FCOMMFG FRATING_ORI FRATING_DTE FRATING_RP
# 0        0       Y          10  20210426.0          9
# 1        0       Y           9  20220225.0          8
# 2        0       Y           9         NaN         10
# 3        0       Y           8  20210628.0          8
# 4        0       Y           8  20190920.0         10
#
# [5 rows x 73 columns]

# %%
# ข้อมูลเชิงสถิติ
# df_tran.describe()
df_tran.describe()
# Out:
#           FRPDATE       FRLDATE       FORDATE      FMATDATE        FCUSNO  \
# count      1116.0  1.116000e+03  1.116000e+03  1.116000e+03   1116.000000
# mean   20240731.0  1.973978e+07  2.020975e+07  2.042321e+07  54622.473118
# std           0.0  3.050279e+06  3.637615e+04  1.225688e+05  25867.942904
# min    20240731.0  0.000000e+00  2.005053e+07  2.018062e+07  10111.000000
# 25%    20240731.0  2.020093e+07  2.020122e+07  2.030013e+07  32221.000000
# 50%    20240731.0  2.022101e+07  2.022101e+07  2.045072e+07  54004.000000
# 75%    20240731.0  2.023090e+07  2.023085e+07  2.052123e+07  77152.750000
# max    20240731.0  2.024073e+07  2.024073e+07  2.064061e+07  99987.000000
#
#              FACCNO      FACCSTS      FNPLFDTE      FTDRFDTE      FTDRLDTE  \
# count  1.116000e+03  1116.000000  1.116000e+03  1.116000e+03  1.116000e+03
# mean   5.567600e+09     1.050179  1.249840e+06  3.079023e+05  3.079567e+05
# std    2.610406e+09     0.289099  4.870779e+06  2.476751e+06  2.477188e+06
# min    1.010034e+09     1.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.356476e+09     1.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    5.581033e+09     1.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    7.814797e+09     1.000000  0.000000e+00  0.000000e+00  0.000000e+00
# max    9.996847e+09     3.000000  2.024070e+07  2.024073e+07  2.024073e+07
#
#        ...      FDAYPAY       FPRNPAY       FINTPAY      FFEEPAY     FCUSTYPE  \
# count  ...  1116.000000  1.116000e+03  1.116000e+03  1116.000000  1116.000000
# mean   ...    12.990143  1.878063e+06  2.026784e+04     0.141953  5890.086022
# std    ...    12.341584  5.987192e+07  1.675069e+05     4.145663   290.873550
# min    ...     0.000000 -1.131000e+06  0.000000e+00     0.000000  4101.000000
# 25%    ...     1.000000  4.023250e+02  1.569325e+02     0.000000  6001.000000
# 50%    ...     5.000000  1.843550e+03  1.786175e+03     0.000000  6001.000000
# 75%    ...    27.000000  9.128952e+03  8.849005e+03     0.000000  6001.000000
# max    ...    31.000000  2.000000e+09  4.565909e+06   137.380000  6001.000000
#
#            FBUSTYPE     FDPDUE00  FRATING_ORI   FRATING_DTE   FRATING_RP
# count  1.116000e+03  1116.000000  1116.000000  9.090000e+02  1116.000000
# mean   9.339707e+07    38.054659     5.967742  2.021296e+07     5.667563
# std    1.467455e+07   230.610268     2.606105  2.474738e+04     2.348870
# min    5.210134e+07     0.000000     1.000000  2.014072e+07     1.000000
# 25%    9.924101e+07     0.000000     4.000000  2.020062e+07     4.000000
# 50%    9.924101e+07     0.000000     5.000000  2.022072e+07     5.000000
# 75%    9.924200e+07     0.000000     7.000000  2.023053e+07     6.000000
# max    9.924201e+07  3039.000000    18.000000  2.024072e+07    18.000000
#
# [8 rows x 30 columns]

# %%
# ดูค่า category
print(df_tran['FPRODTY'].value_counts())
# Out:
# FPRODTY
# H1    484
# PG    115
# PA     83
# PP     68
# PE     67
# P9     57
# PC     36
# F2     35
# P4     29
# AA     26
# E6     18
# TR     17
# V2     12
# E5     10
# FA      7
# E2      7
# PB      6
# E1      5
# S2      5
# PM      5
# D2      5
# P8      4
# F8      3
# PL      2
# OT      2
# EA      2
# F1      2
# P1      1
# F5      1
# D4      1
# XV      1
# Name: count, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## Section 2.3 — การทำความสะอาดข้อมูล (Data Cleaning)
#
# ### 2.3.1 การจัดการข้อมูลที่หายไป (Missing Data)
#
# สรุป: ตัดสินใจว่าจะลบแถวที่มีค่าว่างหรือเติมค่า (business rule) เช่น DPD ว่างอาจหมายถึง 0

# %%
# ตัวอย่าง fillna
print(f"DPD missing count before: {df_tran['FDPDUE00'].isnull().sum()}")
df_tran.fillna({'FDPDUE00': 0}, inplace=True)
print(f"DPD missing count after: {df_tran['FDPDUE00'].isnull().sum()}")
# Out:
# DPD missing count before: 0
# DPD missing count after: 0

# %% [markdown]
# ---

# %% [markdown]
# ### 2.3.2 การแปลงประเภทข้อมูล (Type Conversion)
#
# ฟังก์ชันสำคัญ: `astype()`, `pd.to_datetime()`, `pd.to_numeric()`

# %%
# แปลงวันที่จากรูปตัวเลข เช่น 20240731
df_tran['FRPDATE'] = pd.to_datetime(df_tran['FRPDATE'], format='%Y%m%d')

# แปลง FNPLFDTE โดยไม่สามารถแปลงได้จะกลายเป็น NaT
df_tran['FNPLFDTE'] = pd.to_datetime(df_tran['FNPLFDTE'], format='%Y%m%d', errors='coerce')

# %% [markdown]
# ---

# %% [markdown]
# ### 2.3.3 ลบข้อมูลที่ไม่จำเป็น (Duplicates & Dropping)

# %%
# ลบคอลัมน์ Watchlist ที่ไม่จำเป็น
cols_to_drop = [f'FWLSTF{i:02d}' for i in range(1, 31)]
df_tran.drop(columns=cols_to_drop, inplace=True, errors='ignore')

# ลบแถวซ้ำ
df_tran.drop_duplicates(inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# ## Section 2.4 — การรวมและจัดรูปข้อมูล (Data Transformation)
#
# ### 2.4.1 การเลือกและกรอง (Selecting & Filtering)

# %%
# เลือกคอลัมน์
s_principal = df_tran['FPRINCAM']
# เลือก subset
df_subset = df_tran[['FCUSNO', 'FACCNO', 'FPRINCAM', 'FDPDUE00']]
# กรอง DPD > 0
df_overdue = df_tran[df_tran['FDPDUE00'] > 0]
# กรอง NPL (DPD > 90)
df_npl = df_tran.loc[df_tran['FDPDUE00'] > 90]

# %% [markdown]
# ---

# %% [markdown]
# ### 2.4.2 การรวมข้อมูล (Combining DataFrames)
#
# สรุป: `pd.concat()` ต่อแนวตั้ง, `pd.merge()` สำหรับการ join (เทียบ VLOOKUP)

# %%
# ตัวอย่าง merge (left join)
df_merged = pd.merge(df_tran, df_perf, left_on='FCUSNO', right_on='CIF', how='inner')
df_merged.shape
# Out:
# (266, 46)

# %%
df_merged.head()
# Out:
#    FRPDATE_x   FRLDATE   FORDATE  FMATDATE  FCUSNO      FACCNO FLNTYP  \
# 0 2024-07-31  20070323  20070323  20460323   52005  5579906439      L
# 1 2024-07-31  20070323  20070323  20460323   52005  5579906439      L
# 2 2024-07-31  20070323  20070323  20460323   52005  5579906439      L
# 3 2024-07-31  20070323  20070323  20460323   52005  5579906439      L
# 4 2024-07-31  20070323  20070323  20460323   52005  5579906439      L
#
#    FACCSTS FPRODTY FNPLFDTE  ... FSGMCOD  FCARID00  FDPDUE00  FCOMMFG  \
# 0        1      H1      NaT  ...      HL         A         0        Y
# 1        1      H1      NaT  ...      HL         A         0        Y
# 2        1      H1      NaT  ...      HL         A         0        Y
# 3        1      H1      NaT  ...      HL         A         0        Y
# 4        1      H1      NaT  ...      HL         A         0        Y
#
#   FRATING_ORI  FRATING_DTE  FRATING_RP  FRPDATE_y    CIF  STAGE_CIF
# 0           5          NaN           5   20240731  52005          3
# 1           5          NaN           5   20240831  52005          3
# 2           5          NaN           5   20240930  52005          3
# 3           5          NaN           5   20241031  52005          3
# 4           5          NaN           5   20241130  52005          3
#
# [5 rows x 46 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Section 2.5 — Mini-Game: Review Game — Challenge
#
# จับคู่ "สิ่งที่เราอยากทำ" กับ "โค้ด Pandas ที่ถูกต้อง (A–F)" แล้วค่อยเลื่อนไปดูเฉลยด้านล่าง
#
# | สิ่งที่เราอยากทำ (ข้อ) | ตัวเลือกของคุณ (A–F) |
# |---|---|
# | 1. โหลดไฟล์ Transection_20240731.csv เข้ามาใน Python | ___ |
# | 2. รวมตาราง df_tran กับ df_perf โดยใช้ FCUSNO และ CIF เป็นคีย์ | ___ |
# | 3. ดูค่าสถิติเบื้องต้น (mean, max, min) ของคอลัมน์ตัวเลข | ___ |
# | 4. เลือกเฉพาะแถวที่ FDPDUE01 > 0 | ___ |
# | 5. เติม 0 ในช่องว่างของคอลัมน์ FDPDUE01 | ___ |
# | 6. แปลงคอลัมน์ FRPDATE เป็น datetime | ___ |
#
# **ตัวเลือกโค้ด (A–F)**
#
# | ตัวอักษร | โค้ดตัวอย่าง |
# |---|---|
# | A | `df_tran[df_tran['FDPDUE01'] > 0]` |
# | B | `df_tran['FDPDUE01'].fillna(0, inplace=True)` |
# | C | `pd.merge(df_tran, df_perf, left_on='FCUSNO', right_on='CIF', how='left')` |
# | D | `df_tran.describe()` |
# | E | `pd.to_datetime(df_tran['FRPDATE'], format='%Y%m%d')` |
# | F | `pd.read_csv('Transection_20240731.csv')` |
#
# ---

# %% [markdown]
# ## Review Game — เฉลย
#
# | สิ่งที่เราอยากทำ (ข้อ) | โค้ดที่ถูกต้อง (ตัวอักษร) |
# |---|---|
# | 1. โหลดไฟล์ Transection_20240731.csv เข้ามาใน Python | F |
# | 2. รวมตาราง df_tran กับ df_perf โดยใช้ FCUSNO และ CIF เป็นคีย์ | C |
# | 3. ดูค่าสถิติเบื้องต้น (mean, max, min) ของคอลัมน์ตัวเลข | D |
# | 4. เลือกเฉพาะแถวที่ FDPDUE01 > 0 | A |
# | 5. เติม 0 ในช่องว่างของคอลัมน์ FDPDUE01 | B |
# | 6. แปลงคอลัมน์ FRPDATE เป็น datetime | E |
#
# ---
#
# ### What you learned
#
# - การนำเข้าและสำรวจข้อมูลเบื้องต้นด้วย Pandas
# - การจัดการค่าว่าง และการแปลงประเภทวันที่
# - การกรองและรวมตารางเพื่อเตรียมข้อมูลสำหรับวิเคราะห์
#
# ---
